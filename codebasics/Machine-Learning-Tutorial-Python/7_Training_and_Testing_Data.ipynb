# %%
import pandas as pd

# %%
df = pd.read_csv("./datasets/carprices.csv", usecols=['Mileage', 'Age(yrs)', 'Sell Price($)'])
df.head()
# Out:
#    Mileage  Sell Price($)  Age(yrs)
# 0    69000          18000         6
# 1    35000          34000         3
# 2    57000          26100         5
# 3    22500          40000         2
# 4    46000          31500         4

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Mileage'], df['Sell Price($)'])
plt.title('Car Mileage Vs Sell Price ($)')
plt.xlabel('Mileage')
plt.ylabel('Sell Price($)')
plt.show()

# %%
plt.scatter(df['Age(yrs)'], df['Sell Price($)'])
plt.title('Car Age Vs Sell Price ($)')
plt.xlabel('Age(yrs)')
plt.ylabel('Sell Price($)')
plt.show()

# %%
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# %%
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %%
len(X_train)
# Out:
# 9

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 8     91000         8
# 2     57000         5
# 12    59000         5
# 5     59000         5
# 10    83000         7
# 1     35000         3
# 0     69000         6
# 4     46000         4
# 9     67000         6

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([39514.67542812, 26018.35921943, 15957.74591796, 19906.88968538])

# %%
y_test
# Out:
# 3     40000
# 7     19300
# 11    21000
# 6     32000
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test, y_test)
# Out:
# 0.23756827227998112
